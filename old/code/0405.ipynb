# %%
import torch
import torchvision
from torch.utils.data import Dataset
from os import listdir
from os.path import join
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.parameter import Parameter
from torch.autograd import Variable
import torch.optim as optim
from tqdm import tqdm
import os, copy, argparse, configparser
import sys, datetime, csv, random
from tqdm import tqdm
from torchmetrics import PeakSignalNoiseRatio
import pytorch_lightning as pl
from torchvision.utils import save_image
import network_models as models
import function_losses as losses
# import pytorch_model_summary as mosum
from PIL import Image

# ======================================================================
# take options 
# ======================================================================
parser = argparse.ArgumentParser()
parser.add_argument("--dir_work", type=str, default='/nas/users/minhyeok/energy_based_model')
parser.add_argument("--device_cuda", type=int, default=0)

parser.add_argument("--model_conv", type=str, default='conv_double_resnet')
parser.add_argument("--model_activation", type=str, default='leakyrelu')
parser.add_argument("--model_output", type=str, default='tanh')
parser.add_argument("--model_use_batch_norm", type=eval, default=False, choices=[True, False])
parser.add_argument("--model_use_skip", type=eval, default=False, choices=[True, False])
parser.add_argument("--model_use_dual_input", type=eval, default=False, choices=[True, False])
parser.add_argument("--model_dim_feature", type=int, default=16)
parser.add_argument("--model_dim_latent", type=int, default=100)

parser.add_argument("--data_name", type=str, default='MNIST')
parser.add_argument("--data_use_all", type=eval, default=False, choices=[True, False])
parser.add_argument("--data_label_subset", type=int, default=5)
parser.add_argument("--data_channel", type=int, default=1)
parser.add_argument("--image_size", type=int, default=32)
parser.add_argument("--data_noise_sigma", type=float, default=0.15)

parser.add_argument("--optim_option", type=str, default='adam')
parser.add_argument("--optim_length_epoch", type=int, default=510)
parser.add_argument("--optim_size_batch", type=int, default=100)
parser.add_argument("--optim_lr_model", type=float, default=0.01)
parser.add_argument("--optim_lr_energy", type=float, default=0.01)
parser.add_argument("--optim_lr_data", type=float, default=0.01)
parser.add_argument("--optim_lr_langevin", type=float, default=0.0001)
parser.add_argument("--optim_length_langevin", type=int, default=10)
parser.add_argument("--optim_weight_gradient", type=float, default=0.0001)
parser.add_argument("--optim_weight_regular", type=float, default=0.0001)

args = parser.parse_args(args=[])

# ======================================================================
# assign options
# ======================================================================
dir_work                = args.dir_work
device_cuda             = args.device_cuda

model_conv              = args.model_conv
model_activation        = args.model_activation
model_output            = args.model_output
model_use_batch_norm    = args.model_use_batch_norm
model_use_skip          = args.model_use_skip
model_use_dual_input    = args.model_use_dual_input
model_dim_feature       = args.model_dim_feature
model_dim_latent        = args.model_dim_latent

data_name               = args.data_name.upper()
data_use_all            = args.data_use_all
data_label_subset       = args.data_label_subset 
data_channel            = args.data_channel
img_size                = args.image_size
data_noise_sigma        = args.data_noise_sigma

optim_option            = args.optim_option
optim_length_epoch      = args.optim_length_epoch
optim_size_batch        = args.optim_size_batch
optim_lr_model          = args.optim_lr_model
optim_lr_energy         = args.optim_lr_energy
optim_lr_data           = args.optim_lr_data
optim_lr_langevin       = args.optim_lr_langevin
optim_length_langevin   = args.optim_length_langevin
optim_weight_gradient   = args.optim_weight_gradient
optim_weight_regular    = args.optim_weight_regular

# ======================================================================
# path for the results
# ======================================================================
now         = datetime.datetime.now()
date_stamp  = now.strftime('%Y_%m_%d') 
time_stamp  = now.strftime('%H_%M_%S') 

dir_figure  = os.path.join(dir_work, 'figure')
dir_option  = os.path.join(dir_work, 'option')
dir_result  = os.path.join(dir_work, 'result')
dir_model   = os.path.join(dir_work, 'model')

path_figure = os.path.join(dir_figure, data_name)
path_option = os.path.join(dir_option, data_name)
path_result = os.path.join(dir_result, data_name)
path_model  = os.path.join(dir_model, data_name)

date_figure = os.path.join(path_figure, date_stamp)
date_option = os.path.join(path_option, date_stamp)
date_result = os.path.join(path_result, date_stamp)
date_model  = os.path.join(path_model, date_stamp)

file_figure = os.path.join(date_figure, '{}.png'.format(time_stamp))
file_option = os.path.join(date_option, '{}.ini'.format(time_stamp))
file_result = os.path.join(date_result, '{}.csv'.format(time_stamp))
file_model  = os.path.join(date_model, '{}.pth'.format(time_stamp))

if not os.path.exists(dir_figure):
    os.mkdir(dir_figure)
if not os.path.exists(dir_option):
    os.mkdir(dir_option)
if not os.path.exists(dir_result):
    os.mkdir(dir_result)
if not os.path.exists(dir_model):
    os.mkdir(dir_model)
if not os.path.exists(path_figure):
    os.mkdir(path_figure)
if not os.path.exists(path_option):
    os.mkdir(path_option)
if not os.path.exists(path_result):
    os.mkdir(path_result)
if not os.path.exists(path_model):
    os.mkdir(path_model)
if not os.path.exists(date_figure):
    os.mkdir(date_figure)
if not os.path.exists(date_option):
    os.mkdir(date_option)
if not os.path.exists(date_result):
    os.mkdir(date_result)
if not os.path.exists(date_model):
    os.mkdir(date_model)

device = torch.device(f'cuda:{device_cuda}' if torch.cuda.is_available() else 'mps')

# ======================================================================
# random seed
# ======================================================================
pl.seed_everything(0)

# ======================================================================
# dataset 
# ======================================================================
dir_data = '/nas/users/minhyeok/dataset'

transform = torchvision.transforms.Compose([ 
    torchvision.transforms.Resize(img_size),
    torchvision.transforms.ToTensor(),
    # torchvision.transforms.Lambda(lambda t: (t - torch.mean(t)) / torch.std(t)) # mean 0, std 1
    # torchvision.transforms.Lambda(lambda t: 2.0 * t - 1) 
])

# the name of the dataset is used as upper case
if data_name == 'MNIST':
    dataset         = torchvision.datasets.MNIST(dir_data, transform=transform, train=True, download=True)
    dataset_test    = torchvision.datasets.MNIST(dir_data, transform=transform, train=False, download=True)

elif data_name == 'CIFAR10':
    dataset                 = torchvision.datasets.CIFAR10(dir_data, transform=transform, train=True, download=True)
    dataset.data            = np.array(dataset.data)
    dataset.targets         = np.array(dataset.targets)
    dataset_test            = torchvision.datasets.CIFAR10(dir_data, transform=transform, train=False, download=True)
    dataset_test.data       = np.array(dataset_test.data)
    dataset_test.targets    = np.array(dataset_test.targets)

elif data_name == 'CELEBA':
    dataset = torchvision.datasets.CelebA(dir_data, transform=transform, download=True)
    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size
    dataset, dataset_test = torch.utils.data.random_split(dataset, [train_size, test_size])
   
if data_name == 'MNIST' or data_name == 'CIFAR10': 
    if not data_use_all:
        idx_label               = (dataset.targets==data_label_subset)
        dataset.data            = dataset.data[idx_label]
        dataset.targets         = dataset.targets[idx_label]
        
        idx_label               = (dataset_test.targets==data_label_subset)
        dataset_test.data       = dataset_test.data[idx_label]
        dataset_test.targets    = dataset_test.targets[idx_label]

    num_data_real       = len(dataset)
    number_data_real    = 5000
    dataset.data        = dataset.data[0:number_data_real]
    dataset.targets     = dataset.targets[0:number_data_real]

dataloader      = torch.utils.data.DataLoader(dataset=dataset, batch_size=optim_size_batch*2, drop_last=True, shuffle=True)
dataloader_test = torch.utils.data.DataLoader(dataset=dataset_test, batch_size=optim_size_batch, drop_last=True, shuffle=True)


# ======================================================================
# model
# ======================================================================
model = models.auto_encoder2(
            dim_channel=data_channel,
            dim_feature=model_dim_feature,
            dim_latent=model_dim_latent,
            use_batch_norm=model_use_batch_norm, 
            activation_output=model_output).to(device)

energy = models.energy(
            dim_channel=data_channel,
            dim_feature=model_dim_feature,
            dim_latent=32,
            use_batch_norm=False,
            use_dual_input=model_use_dual_input).to(device)


if optim_option.lower() == 'sgd':
    optim_model     = torch.optim.SGD(model.parameters(), lr=optim_lr_model)
    optim_energy    = torch.optim.SGD(energy.parameters(), lr=optim_lr_energy)
elif optim_option.lower() == 'adam':
    optim_model     = torch.optim.Adam(model.parameters(), lr=optim_lr_model)
    optim_energy    = torch.optim.Adam(energy.parameters(), lr=optim_lr_energy)
elif optim_option.lower() == 'adamw':
    optim_model     = torch.optim.AdamW(model.parameters(), lr=optim_lr_model)
    optim_energy    = torch.optim.AdamW(energy.parameters(), lr=optim_lr_energy)


scheduler_model     = torch.optim.lr_scheduler.ReduceLROnPlateau(optim_model, factor=0.0001, patience=10, mode='min')
scheduler_energy    = torch.optim.lr_scheduler.ReduceLROnPlateau(optim_energy, factor=0.0001, patience=10, mode='min')

# ======================================================================
# evaluation 
# ======================================================================
psnr = PeakSignalNoiseRatio().to(device)

# ======================================================================
# training 
# ======================================================================
val_loss_model_mean     = np.zeros(optim_length_epoch)
val_loss_model_std      = np.zeros(optim_length_epoch)
val_loss_energy_mean    = np.zeros(optim_length_epoch)
val_loss_energy_std     = np.zeros(optim_length_epoch)
val_psnr_mean           = np.zeros(optim_length_epoch)
val_psnr_std            = np.zeros(optim_length_epoch)
val_psnr_update_mean    = np.zeros(optim_length_epoch)
val_psnr_update_std     = np.zeros(optim_length_epoch)
# Out:
# Global seed set to 0

# %%
model.train()
energy.train()

for i in range(optim_length_epoch):
    val_loss_model  = []
    val_loss_energy = []
    val_psnr        = []
    val_psnr_update = []

    for j, (image, _) in enumerate(dataloader):
        data, real  = torch.split(image, optim_size_batch, dim=0)
        
        noise       = torch.randn_like(data)
        data_noise  = data + data_noise_sigma * noise
        
        noise       = torch.randn_like(data)
        real_noise  = real + data_noise_sigma * noise
     
        data        = data.to(device) 
        real        = real.to(device) 
        data_noise  = data_noise.to(device)
        real_noise  = real_noise.to(device)
        
        # -------------------------------------------------------------------
        # predictions
        # -------------------------------------------------------------------         
        pred, mu, log_var, z = model(data_noise)
        
        # -------------------------------------------------------------------
        # interpolation
        # -------------------------------------------------------------------         
        alpha   = torch.rand(optim_size_batch, 1, 1, 1)
        alpha   = alpha.expand_as(real).to(device)
        interp  = alpha * real.data + (1 - alpha) * pred.data
        interp  = Parameter(interp, requires_grad=True)

        # -------------------------------------------------------------------
        # predictions
        # -------------------------------------------------------------------
        if model_use_dual_input:
            energy_positive = energy(real_noise, real)        
            energy_negative = energy(data_noise, pred)        
            energy_interp   = energy(interp, interp)
        else:
            energy_positive = energy(real)        
            energy_negative = energy(pred)        
            energy_interp   = energy(interp)
        
        # -------------------------------------------------------------------
        # update energy model 
        # -------------------------------------------------------------------         
        optim_energy.zero_grad()
        loss_positive   = energy.compute_loss_positive(energy_negative, energy_positive)
        loss_gradient   = losses.compute_gradient_penalty(interp, energy_interp)
        loss_energy     = loss_positive + optim_weight_gradient * loss_gradient
        loss_energy.backward()
        optim_energy.step()
        scheduler_energy.step(loss_energy)
        
        # -------------------------------------------------------------------
        # update input fake 
        # -------------------------------------------------------------------
        pred_update = Parameter(pred, requires_grad=True) 

        for k in range(optim_length_langevin): 

            if model_use_dual_input:
                energy_negative = energy(data_noise, pred_update)
            else:
                energy_negative = energy(pred_update)
            
            loss_negative = energy.compute_loss_negative(energy_negative)
            loss_negative.backward()
            noise = torch.randn_like(pred_update.data)    # N(mean=0, std=1)
            pred_update.data = pred_update.data - optim_lr_data * pred_update.grad + optim_lr_langevin * noise
            pred_update.grad.detach_()
            pred_update.grad.zero_() 

        # -------------------------------------------------------------------
        # update model 
        # -------------------------------------------------------------------         
        optim_model.zero_grad()
        pred, mu, log_var, z = model(data_noise)
        loss_model, loss_data, loss_regular = model.compute_loss(pred, pred_update, mu, log_var, optim_weight_regular) 
        loss_model.backward()
        optim_model.step()        
        scheduler_model.step(loss_model)

        value_psnr          = psnr(pred.data, data).detach().cpu().numpy().mean()
        value_psnr_update   = psnr(pred_update.data, data).detach().cpu().numpy().mean()
            
        val_loss_model.append(loss_model.item()) 
        val_loss_energy.append(loss_energy.item()) 
        val_psnr.append(value_psnr)
        val_psnr_update.append(value_psnr_update)
    
    if i % 10 == 0:
        dir_log             = os.path.join(dir_work, 'log')
        file_pred           = os.path.join(dir_log, 'image/pred.png')
        file_pred_update    = os.path.join(dir_log, 'image/pred_update.png')
        file_pred           = os.path.join(dir_log, 'image/{:03d}.png'.format(i))
        file_pred_update    = os.path.join(dir_log, 'image/{:03d}_update.png'.format(i))
        
        save_image(pred.data[:25], file_pred, nrow=5, normalize=True)
        save_image(pred_update.data[:25], file_pred_update, nrow=5, normalize=True)
        
    
    val_loss_model_mean[i]  = np.mean(val_loss_model)
    val_loss_model_std[i]   = np.std(val_loss_model)
    val_loss_energy_mean[i] = np.mean(val_loss_energy)
    val_loss_energy_std[i]  = np.std(val_loss_energy)
    val_psnr_mean[i]        = np.mean(val_psnr)
    val_psnr_std[i]         = np.std(val_psnr)
    val_psnr_update_mean[i] = np.mean(val_psnr_update)
    val_psnr_update_std[i]  = np.std(val_psnr_update)

    log = '[%4d/%4d] loss(model)=%8.7f, loss(energy)=%8.7f, psnr=%4.2f, psnr(update)=%4.2f' % (i, optim_length_epoch, 
                        val_loss_model_mean[i], val_loss_energy_mean[i], val_psnr_mean[i], val_psnr_update_mean[i])
    print(log, flush=True)
    
    if np.isnan(val_loss_model_mean[i]) or np.isnan(val_loss_energy_mean[i]) or val_psnr_mean[i] < 3:
        sys.exit('error')

# -------------------------------------------------------------------
# save the models
# -------------------------------------------------------------------          
torch.save({
    'state_dict_model'      : model.state_dict(),
    'state_dict_energy'     : energy.state_dict(),
    'model_conv'            : model_conv,
    'model_activation'      : model_activation,
    'model_output'          : model_output,
    'model_use_batch_norm'  : model_use_batch_norm,
    'model_use_skip'        : model_use_skip,
    'model_use_dual_input'  : model_use_dual_input,
    'model_dim_feature'     : model_dim_feature,
    'model_dim_latent'      : model_dim_latent,
    'data_name'             : data_name,
    'data_use_all'          : data_use_all,
    'data_label_subset'     : data_label_subset,
    'data_channel'          : data_channel,
    'data_size  '           : img_size,
    'data_noise_sigma'      : data_noise_sigma,
    'optim_option'          : optim_option,
    'optim_length_epoch'    : optim_length_epoch,
    'optim_size_batch'      : optim_size_batch,
    'optim_lr_model'        : optim_lr_model,
    'optim_lr_energy'       : optim_lr_energy,
    'optim_lr_data'         : optim_lr_data,
    'optim_lr_langevin'     : optim_lr_langevin,
    'optim_length_langevin' : optim_length_langevin,
    'optim_weight_gradient' : optim_weight_gradient,
    'optim_weight_regular'  : optim_weight_regular,
}, file_model)


# -------------------------------------------------------------------
# save the options
# -------------------------------------------------------------------         
with open(file_option, 'w') as f:
    f.write('{}: {}\n'.format('model_conv', model_conv))
    f.write('{}: {}\n'.format('model_activation', model_activation))
    f.write('{}: {}\n'.format('model_output', model_output))
    f.write('{}: {}\n'.format('model_use_batch_norm', model_use_batch_norm))
    f.write('{}: {}\n'.format('model_use_skip', model_use_skip))
    f.write('{}: {}\n'.format('model_use_dual_input', model_use_dual_input))
    f.write('{}: {}\n'.format('model_dim_feature', model_dim_feature))
    f.write('{}: {}\n'.format('model_dim_latent', model_dim_latent))
    f.write('{}: {}\n'.format('data_name', data_name))
    f.write('{}: {}\n'.format('data_use_all', data_use_all))
    f.write('{}: {}\n'.format('data_label_subset', data_label_subset))
    f.write('{}: {}\n'.format('data_channel', data_channel))
    f.write('{}: {}\n'.format('image_size', img_size))
    f.write('{}: {}\n'.format('data_noise_sigma', data_noise_sigma))
    f.write('{}: {}\n'.format('optim_option', optim_option))
    f.write('{}: {}\n'.format('optim_length_epoch', optim_length_epoch))
    f.write('{}: {}\n'.format('optim_size_batch', optim_size_batch))
    f.write('{}: {}\n'.format('optim_lr_model', optim_lr_model))
    f.write('{}: {}\n'.format('optim_lr_energy', optim_lr_energy))
    f.write('{}: {}\n'.format('optim_lr_data', optim_lr_data))
    f.write('{}: {}\n'.format('optim_lr_langevin', optim_lr_langevin))
    f.write('{}: {}\n'.format('optim_length_langevin', optim_length_langevin))
    f.write('{}: {}\n'.format('optim_weight_gradient', optim_weight_gradient))
    f.write('{}: {}\n'.format('optim_weight_regular', optim_weight_regular))
f.close()
    
# -------------------------------------------------------------------
# save training results
# -------------------------------------------------------------------         
data        = data.detach().cpu().numpy().squeeze()
data_noise  = data_noise.detach().cpu().numpy().squeeze()
pred        = pred.detach().cpu().numpy().squeeze()
pred_update = pred_update.detach().cpu().numpy().squeeze()
# Out:
# [   0/ 510] loss(model)=0.0109287, loss(energy)=-25.5769128, psnr=9.94, psnr(update)=9.98
# [   1/ 510] loss(model)=0.0046686, loss(energy)=-59.9860048, psnr=10.14, psnr(update)=10.16
# [   2/ 510] loss(model)=0.0046447, loss(energy)=-60.3870645, psnr=10.18, psnr(update)=10.16
# [   3/ 510] loss(model)=0.0043296, loss(energy)=-60.0070065, psnr=10.17, psnr(update)=10.22
# [   4/ 510] loss(model)=0.0049818, loss(energy)=-59.9048111, psnr=10.16, psnr(update)=10.22
# [   5/ 510] loss(model)=0.0045002, loss(energy)=-60.1484561, psnr=10.21, psnr(update)=10.22
# [   6/ 510] loss(model)=0.0053833, loss(energy)=-59.9467136, psnr=10.12, psnr(update)=10.20
# [   7/ 510] loss(model)=0.0047004, loss(energy)=-58.8099234, psnr=10.12, psnr(update)=10.21
# [   8/ 510] loss(model)=0.0043333, loss(energy)=-59.6159030, psnr=10.22, psnr(update)=10.18
# [   9/ 510] loss(model)=0.0039633, loss(energy)=-59.7094949, psnr=10.16, psnr(update)=10.16
# [  10/ 510] loss(model)=0.0042494, loss(energy)=-59.2465179, psnr=10.18, psnr(update)=10.24
# [  11/ 510] loss(model)=0.0045859, loss(energy)=-60.4521207, psnr=10.17, psnr(update)=10.18
# [  12/ 510] loss(model)=0.0047213, loss(energy)=-59.2595221, psnr=10.20, psnr(update)=10.21
# [  13/ 510] loss(model)=0.0041056, loss(energy)=-59.6856461, psnr=10.15, psnr(update)=10.21
# [  14/ 510] loss(model)=0.0047230, loss(energy)=-60.5884262, psnr=10.20, psnr(update)=10.17
# [  15/ 510] loss(model)=0.0041070, loss(energy)=-60.8462970, psnr=10.20, psnr(update)=10.18
# [  16/ 510] loss(model)=0.0036534, loss(energy)=-58.8431003, psnr=10.18, psnr(update)=10.24
# [  17/ 510] loss(model)=0.0036725, loss(energy)=-59.0527881, psnr=10.16, psnr(update)=10.17
# [  18/ 510] loss(model)=0.0048572, loss(energy)=-61.8824619, psnr=10.20, psnr(update)=10.17
# [  19/ 510] loss(model)=0.0049832, loss(energy)=-59.1810608, psnr=10.16, psnr(update)=10.13
# [  20/ 510] loss(model)=0.0048389, loss(energy)=-60.2298236, psnr=10.16, psnr(update)=10.21
# [  21/ 510] loss(model)=0.0059166, loss(energy)=-59.7568628, psnr=10.13, psnr(update)=10.19
# [  22/ 510] loss(model)=0.0037610, loss(energy)=-60.1539386, psnr=10.22, psnr(update)=10.27
# [  23/ 510] loss(model)=0.0039727, loss(energy)=-58.6791644, psnr=10.18, psnr(update)=10.16
# [  24/ 510] loss(model)=0.0051451, loss(energy)=-61.0165588, psnr=10.18, psnr(update)=10.16
# [  25/ 510] loss(model)=0.0033651, loss(energy)=-58.6510019, psnr=10.18, psnr(update)=10.18
# [  54/ 510] loss(model)=0.0047761, loss(energy)=-60.3254584, psnr=10.12, psnr(update)=10.15
# [  55/ 510] loss(model)=0.0035717, loss(energy)=-60.4443307, psnr=10.25, psnr(update)=10.26
# [  56/ 510] loss(model)=0.0042856, loss(energy)=-61.0639264, psnr=10.23, psnr(update)=10.14
# [  57/ 510] loss(model)=0.0054028, loss(energy)=-58.5178000, psnr=10.11, psnr(update)=10.18
# [  58/ 510] loss(model)=0.0036560, loss(energy)=-59.8302393, psnr=10.21, psnr(update)=10.22
# [  59/ 510] loss(model)=0.0049120, loss(energy)=-59.5476154, psnr=10.22, psnr(update)=10.19
# [  60/ 510] loss(model)=0.0042088, loss(energy)=-59.9484622, psnr=10.16, psnr(update)=10.19
# [  61/ 510] loss(model)=0.0051597, loss(energy)=-58.8906314, psnr=10.15, psnr(update)=10.18
# [  62/ 510] loss(model)=0.0042734, loss(energy)=-59.1755255, psnr=10.15, psnr(update)=10.18
# [  63/ 510] loss(model)=0.0037520, loss(energy)=-59.0731558, psnr=10.18, psnr(update)=10.22
# [  64/ 510] loss(model)=0.0049207, loss(energy)=-58.9394769, psnr=10.13, psnr(update)=10.20
# [  65/ 510] loss(model)=0.0046183, loss(energy)=-59.8373502, psnr=10.13, psnr(update)=10.19
# [  66/ 510] loss(model)=0.0049226, loss(energy)=-59.0812164, psnr=10.13, psnr(update)=10.20
# [  67/ 510] loss(model)=0.0037220, loss(energy)=-60.1874774, psnr=10.21, psnr(update)=10.23
# [  68/ 510] loss(model)=0.0046767, loss(energy)=-61.3542743, psnr=10.17, psnr(update)=10.22
# [  69/ 510] loss(model)=0.0052264, loss(energy)=-60.8442416, psnr=10.15, psnr(update)=10.13
# [  70/ 510] loss(model)=0.0047721, loss(energy)=-60.1564368, psnr=10.17, psnr(update)=10.20
# [  71/ 510] loss(model)=0.0040426, loss(energy)=-59.7618588, psnr=10.19, psnr(update)=10.19
# [  72/ 510] loss(model)=0.0055293, loss(energy)=-60.1887701, psnr=10.17, psnr(update)=10.20
# [  73/ 510] loss(model)=0.0048749, loss(energy)=-59.1102719, psnr=10.13, psnr(update)=10.15
# [  74/ 510] loss(model)=0.0043204, loss(energy)=-59.5628366, psnr=10.14, psnr(update)=10.20
# [  75/ 510] loss(model)=0.0038691, loss(energy)=-60.2000729, psnr=10.15, psnr(update)=10.16
# [  76/ 510] loss(model)=0.0039765, loss(energy)=-57.2401154, psnr=10.18, psnr(update)=10.18
# [  77/ 510] loss(model)=0.0046148, loss(energy)=-60.0701019, psnr=10.18, psnr(update)=10.21
# [  78/ 510] loss(model)=0.0043299, loss(energy)=-59.7381305, psnr=10.18, psnr(update)=10.18
# [  79/ 510] loss(model)=0.0041364, loss(energy)=-59.3154962, psnr=10.19, psnr(update)=10.20
# [  80/ 510] loss(model)=0.0054202, loss(energy)=-59.9653714, psnr=10.16, psnr(update)=10.14
# [  81/ 510] loss(model)=0.0044889, loss(energy)=-59.3604181, psnr=10.20, psnr(update)=10.19
# [ 110/ 510] loss(model)=0.0045856, loss(energy)=-58.6958871, psnr=10.12, psnr(update)=10.16
# [ 111/ 510] loss(model)=0.0047188, loss(energy)=-60.5700256, psnr=10.19, psnr(update)=10.22
# [ 112/ 510] loss(model)=0.0044168, loss(energy)=-59.8389297, psnr=10.18, psnr(update)=10.20
# [ 113/ 510] loss(model)=0.0048558, loss(energy)=-59.5440173, psnr=10.19, psnr(update)=10.10
# [ 114/ 510] loss(model)=0.0046026, loss(energy)=-58.5238321, psnr=10.18, psnr(update)=10.21
# [ 115/ 510] loss(model)=0.0045620, loss(energy)=-60.6582028, psnr=10.15, psnr(update)=10.23
# [ 116/ 510] loss(model)=0.0059055, loss(energy)=-60.3798627, psnr=10.13, psnr(update)=10.18
# [ 117/ 510] loss(model)=0.0052960, loss(energy)=-58.7002780, psnr=10.14, psnr(update)=10.15
# [ 118/ 510] loss(model)=0.0064151, loss(energy)=-57.4552295, psnr=10.09, psnr(update)=10.10
# [ 119/ 510] loss(model)=0.0048603, loss(energy)=-58.4616522, psnr=10.14, psnr(update)=10.18
# [ 120/ 510] loss(model)=0.0038308, loss(energy)=-59.2515680, psnr=10.19, psnr(update)=10.17
# [ 121/ 510] loss(model)=0.0040718, loss(energy)=-60.3364578, psnr=10.19, psnr(update)=10.17
# [ 122/ 510] loss(model)=0.0051661, loss(energy)=-59.2117307, psnr=10.17, psnr(update)=10.18
# [ 123/ 510] loss(model)=0.0042689, loss(energy)=-58.4023337, psnr=10.15, psnr(update)=10.14
# [ 124/ 510] loss(model)=0.0042214, loss(energy)=-59.6080649, psnr=10.18, psnr(update)=10.20
# [ 125/ 510] loss(model)=0.0042917, loss(energy)=-60.0094852, psnr=10.17, psnr(update)=10.17
# [ 126/ 510] loss(model)=0.0048240, loss(energy)=-59.0631537, psnr=10.14, psnr(update)=10.13
# [ 127/ 510] loss(model)=0.0045379, loss(energy)=-59.6898044, psnr=10.19, psnr(update)=10.19
# [ 128/ 510] loss(model)=0.0043563, loss(energy)=-59.0333267, psnr=10.13, psnr(update)=10.17
# [ 129/ 510] loss(model)=0.0053106, loss(energy)=-60.1396942, psnr=10.21, psnr(update)=10.17
# [ 130/ 510] loss(model)=0.0034506, loss(energy)=-58.9127448, psnr=10.23, psnr(update)=10.25
# [ 131/ 510] loss(model)=0.0037346, loss(energy)=-59.9740826, psnr=10.23, psnr(update)=10.24
# [ 132/ 510] loss(model)=0.0051273, loss(energy)=-59.4255795, psnr=10.20, psnr(update)=10.13
# [ 133/ 510] loss(model)=0.0049803, loss(energy)=-58.6792389, psnr=10.13, psnr(update)=10.13
# [ 134/ 510] loss(model)=0.0037541, loss(energy)=-60.2270392, psnr=10.18, psnr(update)=10.19
# [ 135/ 510] loss(model)=0.0047205, loss(energy)=-60.5545883, psnr=10.19, psnr(update)=10.15
# [ 136/ 510] loss(model)=0.0047050, loss(energy)=-59.1402142, psnr=10.16, psnr(update)=10.22
# [ 165/ 510] loss(model)=0.0049462, loss(energy)=-59.2497433, psnr=10.11, psnr(update)=10.21
# [ 166/ 510] loss(model)=0.0043713, loss(energy)=-58.9656583, psnr=10.14, psnr(update)=10.22
# [ 167/ 510] loss(model)=0.0046722, loss(energy)=-59.2290646, psnr=10.15, psnr(update)=10.14
# [ 168/ 510] loss(model)=0.0042661, loss(energy)=-60.3209726, psnr=10.19, psnr(update)=10.20
# [ 169/ 510] loss(model)=0.0045218, loss(energy)=-59.5110657, psnr=10.21, psnr(update)=10.19
# [ 170/ 510] loss(model)=0.0053304, loss(energy)=-59.8975085, psnr=10.14, psnr(update)=10.14
# [ 171/ 510] loss(model)=0.0042683, loss(energy)=-61.1653436, psnr=10.22, psnr(update)=10.22
# [ 172/ 510] loss(model)=0.0045962, loss(energy)=-60.2097037, psnr=10.18, psnr(update)=10.25
# [ 173/ 510] loss(model)=0.0051524, loss(energy)=-58.5894638, psnr=10.14, psnr(update)=10.11
# [ 174/ 510] loss(model)=0.0049525, loss(energy)=-59.9943506, psnr=10.18, psnr(update)=10.20
# [ 175/ 510] loss(model)=0.0041564, loss(energy)=-59.8960098, psnr=10.22, psnr(update)=10.24
# [ 176/ 510] loss(model)=0.0041138, loss(energy)=-58.9859888, psnr=10.17, psnr(update)=10.20
# [ 177/ 510] loss(model)=0.0038951, loss(energy)=-59.6010388, psnr=10.21, psnr(update)=10.20
# [ 178/ 510] loss(model)=0.0042979, loss(energy)=-59.8877905, psnr=10.22, psnr(update)=10.21
# [ 179/ 510] loss(model)=0.0044882, loss(energy)=-60.5884610, psnr=10.23, psnr(update)=10.21
# [ 180/ 510] loss(model)=0.0039348, loss(energy)=-59.8046863, psnr=10.16, psnr(update)=10.18
# [ 181/ 510] loss(model)=0.0047210, loss(energy)=-59.4614520, psnr=10.16, psnr(update)=10.23
# [ 182/ 510] loss(model)=0.0039943, loss(energy)=-57.9085718, psnr=10.13, psnr(update)=10.22
# [ 183/ 510] loss(model)=0.0044026, loss(energy)=-59.8655487, psnr=10.15, psnr(update)=10.17
# [ 184/ 510] loss(model)=0.0051801, loss(energy)=-58.6446530, psnr=10.12, psnr(update)=10.16
# [ 185/ 510] loss(model)=0.0047898, loss(energy)=-59.4735645, psnr=10.17, psnr(update)=10.20
# [ 186/ 510] loss(model)=0.0041061, loss(energy)=-59.9300351, psnr=10.17, psnr(update)=10.17
# [ 187/ 510] loss(model)=0.0038204, loss(energy)=-59.5241888, psnr=10.22, psnr(update)=10.19
# [ 188/ 510] loss(model)=0.0041680, loss(energy)=-60.3951038, psnr=10.21, psnr(update)=10.22
# [ 189/ 510] loss(model)=0.0047073, loss(energy)=-59.7071121, psnr=10.20, psnr(update)=10.20
# [ 190/ 510] loss(model)=0.0043511, loss(energy)=-59.5243445, psnr=10.16, psnr(update)=10.17
# [ 191/ 510] loss(model)=0.0042667, loss(energy)=-59.3069650, psnr=10.17, psnr(update)=10.18
# [ 247/ 510] loss(model)=0.0038980, loss(energy)=-58.4879385, psnr=10.19, psnr(update)=10.22
# [ 248/ 510] loss(model)=0.0050557, loss(energy)=-59.0203946, psnr=10.10, psnr(update)=10.13
# [ 249/ 510] loss(model)=0.0048238, loss(energy)=-60.7227209, psnr=10.18, psnr(update)=10.16
# [ 250/ 510] loss(model)=0.0045062, loss(energy)=-60.4619116, psnr=10.19, psnr(update)=10.23
# [ 251/ 510] loss(model)=0.0041774, loss(energy)=-59.4053836, psnr=10.19, psnr(update)=10.19
# [ 252/ 510] loss(model)=0.0047667, loss(energy)=-58.2192923, psnr=10.12, psnr(update)=10.20
# [ 253/ 510] loss(model)=0.0051201, loss(energy)=-59.7327441, psnr=10.15, psnr(update)=10.14
# [ 254/ 510] loss(model)=0.0042580, loss(energy)=-59.5520276, psnr=10.20, psnr(update)=10.15
# [ 255/ 510] loss(model)=0.0052659, loss(energy)=-60.0591150, psnr=10.20, psnr(update)=10.22
# [ 256/ 510] loss(model)=0.0041957, loss(energy)=-58.4655325, psnr=10.15, psnr(update)=10.16
# [ 257/ 510] loss(model)=0.0048316, loss(energy)=-60.1435458, psnr=10.16, psnr(update)=10.18
# [ 258/ 510] loss(model)=0.0051711, loss(energy)=-58.8647546, psnr=10.13, psnr(update)=10.16
# [ 259/ 510] loss(model)=0.0038729, loss(energy)=-60.0014075, psnr=10.25, psnr(update)=10.22
# [ 260/ 510] loss(model)=0.0044959, loss(energy)=-59.6526251, psnr=10.18, psnr(update)=10.19
# [ 261/ 510] loss(model)=0.0039931, loss(energy)=-58.6251886, psnr=10.18, psnr(update)=10.19
# [ 262/ 510] loss(model)=0.0043238, loss(energy)=-59.0475385, psnr=10.22, psnr(update)=10.17
# [ 263/ 510] loss(model)=0.0042982, loss(energy)=-59.4121051, psnr=10.17, psnr(update)=10.16
# [ 264/ 510] loss(model)=0.0037165, loss(energy)=-58.5332224, psnr=10.14, psnr(update)=10.20
# [ 265/ 510] loss(model)=0.0044371, loss(energy)=-60.4537741, psnr=10.14, psnr(update)=10.18
# [ 266/ 510] loss(model)=0.0041524, loss(energy)=-59.0372455, psnr=10.19, psnr(update)=10.17
# [ 267/ 510] loss(model)=0.0062261, loss(energy)=-60.0518976, psnr=10.12, psnr(update)=10.11
# [ 268/ 510] loss(model)=0.0045162, loss(energy)=-58.1201450, psnr=10.16, psnr(update)=10.17
# [ 269/ 510] loss(model)=0.0045556, loss(energy)=-59.6289944, psnr=10.16, psnr(update)=10.21
# [ 270/ 510] loss(model)=0.0043652, loss(energy)=-59.4313654, psnr=10.16, psnr(update)=10.17
# [ 271/ 510] loss(model)=0.0041096, loss(energy)=-59.1593726, psnr=10.18, psnr(update)=10.19
# [ 272/ 510] loss(model)=0.0048135, loss(energy)=-59.7313333, psnr=10.16, psnr(update)=10.17
# [ 273/ 510] loss(model)=0.0050439, loss(energy)=-58.8608749, psnr=10.12, psnr(update)=10.21
# [ 274/ 510] loss(model)=0.0039366, loss(energy)=-58.5939752, psnr=10.19, psnr(update)=10.24
# [ 275/ 510] loss(model)=0.0046842, loss(energy)=-60.6473557, psnr=10.21, psnr(update)=10.17
# [ 276/ 510] loss(model)=0.0044006, loss(energy)=-58.8167361, psnr=10.15, psnr(update)=10.18
# [ 277/ 510] loss(model)=0.0046275, loss(energy)=-59.3339316, psnr=10.21, psnr(update)=10.23
# [ 278/ 510] loss(model)=0.0037250, loss(energy)=-58.3333551, psnr=10.20, psnr(update)=10.22
# [ 279/ 510] loss(model)=0.0041061, loss(energy)=-60.5179514, psnr=10.18, psnr(update)=10.22
# [ 280/ 510] loss(model)=0.0043030, loss(energy)=-61.1068796, psnr=10.18, psnr(update)=10.20
# [ 281/ 510] loss(model)=0.0041703, loss(energy)=-59.0450113, psnr=10.17, psnr(update)=10.18
# [ 282/ 510] loss(model)=0.0040003, loss(energy)=-60.5333939, psnr=10.19, psnr(update)=10.23
# [ 283/ 510] loss(model)=0.0054675, loss(energy)=-59.9746484, psnr=10.16, psnr(update)=10.17
# [ 284/ 510] loss(model)=0.0052148, loss(energy)=-59.3325104, psnr=10.17, psnr(update)=10.16
# [ 285/ 510] loss(model)=0.0051415, loss(energy)=-60.2734216, psnr=10.14, psnr(update)=10.15
# [ 286/ 510] loss(model)=0.0048149, loss(energy)=-60.8785880, psnr=10.22, psnr(update)=10.20
# [ 287/ 510] loss(model)=0.0048000, loss(energy)=-59.0984940, psnr=10.12, psnr(update)=10.20
# [ 288/ 510] loss(model)=0.0053304, loss(energy)=-58.6147235, psnr=10.12, psnr(update)=10.16
# [ 289/ 510] loss(model)=0.0047440, loss(energy)=-60.4762357, psnr=10.20, psnr(update)=10.19
# [ 290/ 510] loss(model)=0.0034757, loss(energy)=-59.3686298, psnr=10.19, psnr(update)=10.22
# [ 291/ 510] loss(model)=0.0044444, loss(energy)=-59.2816586, psnr=10.15, psnr(update)=10.15
# [ 292/ 510] loss(model)=0.0047343, loss(energy)=-60.3788199, psnr=10.13, psnr(update)=10.16
# [ 293/ 510] loss(model)=0.0038997, loss(energy)=-59.8988461, psnr=10.20, psnr(update)=10.17
# [ 294/ 510] loss(model)=0.0045546, loss(energy)=-61.1114624, psnr=10.24, psnr(update)=10.23
# [ 295/ 510] loss(model)=0.0042655, loss(energy)=-60.7062589, psnr=10.18, psnr(update)=10.18
# [ 296/ 510] loss(model)=0.0035678, loss(energy)=-58.3365451, psnr=10.18, psnr(update)=10.22
# [ 297/ 510] loss(model)=0.0053711, loss(energy)=-58.4652997, psnr=10.15, psnr(update)=10.11
# [ 298/ 510] loss(model)=0.0042226, loss(energy)=-60.3794907, psnr=10.18, psnr(update)=10.24
# [ 299/ 510] loss(model)=0.0046432, loss(energy)=-60.2779788, psnr=10.19, psnr(update)=10.18
# [ 300/ 510] loss(model)=0.0048783, loss(energy)=-59.7977222, psnr=10.20, psnr(update)=10.17
# [ 301/ 510] loss(model)=0.0043422, loss(energy)=-60.2330740, psnr=10.18, psnr(update)=10.21
# [ 302/ 510] loss(model)=0.0044465, loss(energy)=-59.6708704, psnr=10.14, psnr(update)=10.18
# [ 303/ 510] loss(model)=0.0043513, loss(energy)=-58.6885822, psnr=10.18, psnr(update)=10.19
# [ 304/ 510] loss(model)=0.0056881, loss(energy)=-60.1062665, psnr=10.10, psnr(update)=10.21
# [ 305/ 510] loss(model)=0.0044468, loss(energy)=-60.2908755, psnr=10.16, psnr(update)=10.20
# [ 306/ 510] loss(model)=0.0044802, loss(energy)=-60.2502298, psnr=10.17, psnr(update)=10.15
# [ 307/ 510] loss(model)=0.0043539, loss(energy)=-58.4340430, psnr=10.17, psnr(update)=10.21
# [ 308/ 510] loss(model)=0.0038043, loss(energy)=-59.7843741, psnr=10.19, psnr(update)=10.20
# [ 309/ 510] loss(model)=0.0040748, loss(energy)=-59.9021323, psnr=10.18, psnr(update)=10.19
# [ 310/ 510] loss(model)=0.0045972, loss(energy)=-59.5083969, psnr=10.20, psnr(update)=10.19
# [ 311/ 510] loss(model)=0.0043724, loss(energy)=-59.3978378, psnr=10.17, psnr(update)=10.22
# [ 312/ 510] loss(model)=0.0038901, loss(energy)=-58.4546075, psnr=10.16, psnr(update)=10.16
# [ 313/ 510] loss(model)=0.0041226, loss(energy)=-60.2448160, psnr=10.21, psnr(update)=10.23
# [ 314/ 510] loss(model)=0.0047178, loss(energy)=-58.4000702, psnr=10.17, psnr(update)=10.12
# [ 315/ 510] loss(model)=0.0050119, loss(energy)=-58.9232330, psnr=10.13, psnr(update)=10.16
# [ 316/ 510] loss(model)=0.0055451, loss(energy)=-59.9307410, psnr=10.18, psnr(update)=10.14
# [ 317/ 510] loss(model)=0.0047271, loss(energy)=-61.1810999, psnr=10.20, psnr(update)=10.23
# [ 318/ 510] loss(model)=0.0041765, loss(energy)=-59.5371747, psnr=10.17, psnr(update)=10.16
# [ 319/ 510] loss(model)=0.0054326, loss(energy)=-60.5927661, psnr=10.20, psnr(update)=10.17
# [ 320/ 510] loss(model)=0.0042250, loss(energy)=-60.5700574, psnr=10.23, psnr(update)=10.22
# [ 321/ 510] loss(model)=0.0049666, loss(energy)=-61.1497083, psnr=10.16, psnr(update)=10.25
# [ 322/ 510] loss(model)=0.0059655, loss(energy)=-58.8302234, psnr=10.11, psnr(update)=10.15
# [ 323/ 510] loss(model)=0.0046603, loss(energy)=-60.2583069, psnr=10.16, psnr(update)=10.19
# [ 324/ 510] loss(model)=0.0041629, loss(energy)=-59.5657416, psnr=10.16, psnr(update)=10.19
# [ 325/ 510] loss(model)=0.0042434, loss(energy)=-59.2965912, psnr=10.13, psnr(update)=10.20
# [ 326/ 510] loss(model)=0.0046430, loss(energy)=-60.4305859, psnr=10.18, psnr(update)=10.18
# [ 327/ 510] loss(model)=0.0046414, loss(energy)=-60.1811261, psnr=10.20, psnr(update)=10.23
# [ 328/ 510] loss(model)=0.0041577, loss(energy)=-59.8753244, psnr=10.18, psnr(update)=10.21
# [ 329/ 510] loss(model)=0.0039870, loss(energy)=-59.3647662, psnr=10.17, psnr(update)=10.17
# [ 330/ 510] loss(model)=0.0038837, loss(energy)=-60.3077075, psnr=10.23, psnr(update)=10.25
# [ 331/ 510] loss(model)=0.0040916, loss(energy)=-59.1014771, psnr=10.20, psnr(update)=10.24
# [ 332/ 510] loss(model)=0.0039897, loss(energy)=-61.0185684, psnr=10.21, psnr(update)=10.24
# [ 333/ 510] loss(model)=0.0045753, loss(energy)=-59.1118872, psnr=10.15, psnr(update)=10.14
# [ 334/ 510] loss(model)=0.0053283, loss(energy)=-61.2078430, psnr=10.17, psnr(update)=10.14
# [ 335/ 510] loss(model)=0.0044600, loss(energy)=-60.5180435, psnr=10.23, psnr(update)=10.19
# [ 336/ 510] loss(model)=0.0037531, loss(energy)=-59.3922302, psnr=10.20, psnr(update)=10.18
# [ 337/ 510] loss(model)=0.0049967, loss(energy)=-60.3096082, psnr=10.12, psnr(update)=10.23
# [ 338/ 510] loss(model)=0.0045086, loss(energy)=-59.3866782, psnr=10.17, psnr(update)=10.17
# [ 339/ 510] loss(model)=0.0053031, loss(energy)=-59.6434610, psnr=10.14, psnr(update)=10.16
# [ 340/ 510] loss(model)=0.0050941, loss(energy)=-61.5905441, psnr=10.22, psnr(update)=10.23
# [ 341/ 510] loss(model)=0.0054621, loss(energy)=-61.0580746, psnr=10.18, psnr(update)=10.21
# [ 342/ 510] loss(model)=0.0043155, loss(energy)=-59.6162363, psnr=10.22, psnr(update)=10.22
# [ 343/ 510] loss(model)=0.0046433, loss(energy)=-59.4947287, psnr=10.15, psnr(update)=10.13
# [ 344/ 510] loss(model)=0.0042125, loss(energy)=-60.4584879, psnr=10.22, psnr(update)=10.18
# [ 345/ 510] loss(model)=0.0045979, loss(energy)=-58.9778452, psnr=10.18, psnr(update)=10.19
# [ 346/ 510] loss(model)=0.0037406, loss(energy)=-59.6940942, psnr=10.22, psnr(update)=10.22
# [ 347/ 510] loss(model)=0.0049962, loss(energy)=-60.1106546, psnr=10.20, psnr(update)=10.20
# [ 348/ 510] loss(model)=0.0051425, loss(energy)=-59.8138403, psnr=10.14, psnr(update)=10.23
# [ 349/ 510] loss(model)=0.0039395, loss(energy)=-60.6322708, psnr=10.25, psnr(update)=10.22
# [ 350/ 510] loss(model)=0.0044870, loss(energy)=-59.1202448, psnr=10.14, psnr(update)=10.18
# [ 351/ 510] loss(model)=0.0052378, loss(energy)=-60.3472705, psnr=10.17, psnr(update)=10.11
# [ 352/ 510] loss(model)=0.0035910, loss(energy)=-59.1529245, psnr=10.18, psnr(update)=10.21
# [ 353/ 510] loss(model)=0.0053173, loss(energy)=-59.4085779, psnr=10.16, psnr(update)=10.17
# [ 354/ 510] loss(model)=0.0048548, loss(energy)=-58.5690826, psnr=10.16, psnr(update)=10.15
# [ 355/ 510] loss(model)=0.0046234, loss(energy)=-60.7722470, psnr=10.22, psnr(update)=10.19
# [ 356/ 510] loss(model)=0.0040296, loss(energy)=-59.1367004, psnr=10.15, psnr(update)=10.19
# [ 357/ 510] loss(model)=0.0041162, loss(energy)=-59.0519421, psnr=10.17, psnr(update)=10.24
# [ 358/ 510] loss(model)=0.0048978, loss(energy)=-59.3166434, psnr=10.16, psnr(update)=10.12
# [ 359/ 510] loss(model)=0.0050888, loss(energy)=-59.8833646, psnr=10.15, psnr(update)=10.13
# [ 360/ 510] loss(model)=0.0042675, loss(energy)=-59.9565298, psnr=10.21, psnr(update)=10.22
# [ 361/ 510] loss(model)=0.0050512, loss(energy)=-59.9757922, psnr=10.16, psnr(update)=10.22
# [ 362/ 510] loss(model)=0.0039185, loss(energy)=-60.9268408, psnr=10.22, psnr(update)=10.21
# [ 363/ 510] loss(model)=0.0050473, loss(energy)=-60.6157211, psnr=10.19, psnr(update)=10.15
# [ 364/ 510] loss(model)=0.0044253, loss(energy)=-59.8036316, psnr=10.18, psnr(update)=10.21
# [ 365/ 510] loss(model)=0.0039834, loss(energy)=-57.7925052, psnr=10.13, psnr(update)=10.15
# [ 366/ 510] loss(model)=0.0042618, loss(energy)=-59.0380847, psnr=10.18, psnr(update)=10.16
# [ 367/ 510] loss(model)=0.0050365, loss(energy)=-60.5328976, psnr=10.15, psnr(update)=10.18
# [ 368/ 510] loss(model)=0.0041976, loss(energy)=-60.1241425, psnr=10.19, psnr(update)=10.21
# [ 369/ 510] loss(model)=0.0049118, loss(energy)=-57.3010794, psnr=10.14, psnr(update)=10.16
# [ 370/ 510] loss(model)=0.0040201, loss(energy)=-60.2351630, psnr=10.20, psnr(update)=10.22
# [ 371/ 510] loss(model)=0.0052587, loss(energy)=-60.2930420, psnr=10.16, psnr(update)=10.16
# [ 372/ 510] loss(model)=0.0040623, loss(energy)=-60.5056268, psnr=10.16, psnr(update)=10.19
# [ 373/ 510] loss(model)=0.0039669, loss(energy)=-58.7596558, psnr=10.21, psnr(update)=10.23
# [ 374/ 510] loss(model)=0.0049499, loss(energy)=-60.4612961, psnr=10.19, psnr(update)=10.18
# [ 375/ 510] loss(model)=0.0038800, loss(energy)=-59.6322668, psnr=10.20, psnr(update)=10.20
# [ 376/ 510] loss(model)=0.0045595, loss(energy)=-58.9670013, psnr=10.16, psnr(update)=10.18
# [ 377/ 510] loss(model)=0.0052022, loss(energy)=-58.2952182, psnr=10.13, psnr(update)=10.16
# [ 378/ 510] loss(model)=0.0042380, loss(energy)=-60.7448663, psnr=10.21, psnr(update)=10.24
# [ 379/ 510] loss(model)=0.0043280, loss(energy)=-59.6903839, psnr=10.20, psnr(update)=10.22
# [ 380/ 510] loss(model)=0.0039616, loss(energy)=-59.3659006, psnr=10.17, psnr(update)=10.19
# [ 381/ 510] loss(model)=0.0044975, loss(energy)=-60.3606787, psnr=10.19, psnr(update)=10.17
# [ 382/ 510] loss(model)=0.0048859, loss(energy)=-59.3947372, psnr=10.19, psnr(update)=10.18
# [ 383/ 510] loss(model)=0.0049198, loss(energy)=-58.5306909, psnr=10.16, psnr(update)=10.14
# [ 384/ 510] loss(model)=0.0043581, loss(energy)=-59.5931915, psnr=10.19, psnr(update)=10.19
# [ 385/ 510] loss(model)=0.0049420, loss(energy)=-60.2021365, psnr=10.17, psnr(update)=10.25
# [ 386/ 510] loss(model)=0.0039929, loss(energy)=-58.7355530, psnr=10.13, psnr(update)=10.20
# [ 387/ 510] loss(model)=0.0043057, loss(energy)=-58.6596201, psnr=10.18, psnr(update)=10.18
# [ 388/ 510] loss(model)=0.0040563, loss(energy)=-60.1459064, psnr=10.18, psnr(update)=10.22
# [ 389/ 510] loss(model)=0.0041679, loss(energy)=-60.2797647, psnr=10.22, psnr(update)=10.19
# [ 390/ 510] loss(model)=0.0046455, loss(energy)=-62.0511102, psnr=10.22, psnr(update)=10.20
# [ 391/ 510] loss(model)=0.0046469, loss(energy)=-59.8310455, psnr=10.19, psnr(update)=10.22
# [ 392/ 510] loss(model)=0.0048690, loss(energy)=-59.3079996, psnr=10.17, psnr(update)=10.18
# [ 393/ 510] loss(model)=0.0046075, loss(energy)=-59.0683435, psnr=10.14, psnr(update)=10.16
# [ 394/ 510] loss(model)=0.0043504, loss(energy)=-61.3801328, psnr=10.20, psnr(update)=10.22
# [ 395/ 510] loss(model)=0.0042662, loss(energy)=-59.3540387, psnr=10.16, psnr(update)=10.20
# [ 396/ 510] loss(model)=0.0042607, loss(energy)=-58.5867148, psnr=10.22, psnr(update)=10.20
# [ 397/ 510] loss(model)=0.0051962, loss(energy)=-59.0839380, psnr=10.12, psnr(update)=10.19
# [ 398/ 510] loss(model)=0.0044854, loss(energy)=-59.2020554, psnr=10.14, psnr(update)=10.19
# [ 399/ 510] loss(model)=0.0043699, loss(energy)=-58.5763644, psnr=10.12, psnr(update)=10.16
# [ 400/ 510] loss(model)=0.0040509, loss(energy)=-60.8076440, psnr=10.17, psnr(update)=10.19
# [ 401/ 510] loss(model)=0.0040192, loss(energy)=-60.0622238, psnr=10.17, psnr(update)=10.15
# [ 402/ 510] loss(model)=0.0042064, loss(energy)=-58.9078552, psnr=10.14, psnr(update)=10.13
# [ 403/ 510] loss(model)=0.0049581, loss(energy)=-59.7673746, psnr=10.20, psnr(update)=10.19
# [ 404/ 510] loss(model)=0.0041990, loss(energy)=-59.6356775, psnr=10.18, psnr(update)=10.17
# [ 405/ 510] loss(model)=0.0040030, loss(energy)=-59.3088309, psnr=10.17, psnr(update)=10.17
# [ 406/ 510] loss(model)=0.0054900, loss(energy)=-58.4148291, psnr=10.10, psnr(update)=10.19
# [ 407/ 510] loss(model)=0.0041007, loss(energy)=-59.5250244, psnr=10.19, psnr(update)=10.20
# [ 408/ 510] loss(model)=0.0045030, loss(energy)=-59.6593048, psnr=10.17, psnr(update)=10.16
# [ 409/ 510] loss(model)=0.0035824, loss(energy)=-60.0731982, psnr=10.23, psnr(update)=10.21
# [ 410/ 510] loss(model)=0.0042698, loss(energy)=-59.3856177, psnr=10.18, psnr(update)=10.20
# [ 411/ 510] loss(model)=0.0052418, loss(energy)=-58.9022211, psnr=10.10, psnr(update)=10.16
# [ 412/ 510] loss(model)=0.0034234, loss(energy)=-58.1633997, psnr=10.20, psnr(update)=10.24
# [ 440/ 510] loss(model)=0.0051460, loss(energy)=-59.1563391, psnr=10.16, psnr(update)=10.15
# [ 441/ 510] loss(model)=0.0044335, loss(energy)=-59.0315219, psnr=10.15, psnr(update)=10.18
# [ 442/ 510] loss(model)=0.0036607, loss(energy)=-59.9026132, psnr=10.20, psnr(update)=10.20
# [ 443/ 510] loss(model)=0.0043037, loss(energy)=-61.1401288, psnr=10.22, psnr(update)=10.23
# [ 444/ 510] loss(model)=0.0040340, loss(energy)=-60.0291995, psnr=10.19, psnr(update)=10.17
# [ 445/ 510] loss(model)=0.0056318, loss(energy)=-58.6610657, psnr=10.12, psnr(update)=10.10
# [ 446/ 510] loss(model)=0.0039507, loss(energy)=-58.2251688, psnr=10.16, psnr(update)=10.18
# [ 447/ 510] loss(model)=0.0051438, loss(energy)=-61.3021912, psnr=10.16, psnr(update)=10.22
# [ 448/ 510] loss(model)=0.0039885, loss(energy)=-58.7311899, psnr=10.19, psnr(update)=10.19
# [ 449/ 510] loss(model)=0.0051334, loss(energy)=-58.5629004, psnr=10.16, psnr(update)=10.15
# [ 450/ 510] loss(model)=0.0040939, loss(energy)=-60.0675821, psnr=10.21, psnr(update)=10.21
# [ 451/ 510] loss(model)=0.0041746, loss(energy)=-59.2325842, psnr=10.15, psnr(update)=10.19
# [ 452/ 510] loss(model)=0.0045755, loss(energy)=-60.5036108, psnr=10.22, psnr(update)=10.26
# [ 453/ 510] loss(model)=0.0045950, loss(energy)=-59.2958273, psnr=10.16, psnr(update)=10.20
# [ 454/ 510] loss(model)=0.0039473, loss(energy)=-59.5718640, psnr=10.20, psnr(update)=10.22
# [ 455/ 510] loss(model)=0.0034257, loss(energy)=-59.1388113, psnr=10.21, psnr(update)=10.23
# [ 456/ 510] loss(model)=0.0042402, loss(energy)=-59.8919330, psnr=10.16, psnr(update)=10.17
# [ 457/ 510] loss(model)=0.0050392, loss(energy)=-59.4849521, psnr=10.13, psnr(update)=10.20
# [ 458/ 510] loss(model)=0.0053032, loss(energy)=-60.1704239, psnr=10.18, psnr(update)=10.18
# [ 459/ 510] loss(model)=0.0044762, loss(energy)=-59.8768256, psnr=10.14, psnr(update)=10.20
# [ 460/ 510] loss(model)=0.0049424, loss(energy)=-60.4685236, psnr=10.16, psnr(update)=10.20
# [ 461/ 510] loss(model)=0.0052263, loss(energy)=-60.0916861, psnr=10.13, psnr(update)=10.18
# [ 462/ 510] loss(model)=0.0049049, loss(energy)=-59.6124231, psnr=10.18, psnr(update)=10.13
# [ 463/ 510] loss(model)=0.0048783, loss(energy)=-58.9276147, psnr=10.16, psnr(update)=10.14
# [ 464/ 510] loss(model)=0.0054777, loss(energy)=-60.5449518, psnr=10.19, psnr(update)=10.17
# [ 465/ 510] loss(model)=0.0052182, loss(energy)=-58.2749341, psnr=10.15, psnr(update)=10.14
# [ 466/ 510] loss(model)=0.0046099, loss(energy)=-59.7543600, psnr=10.21, psnr(update)=10.17
# [ 467/ 510] loss(model)=0.0046980, loss(energy)=-58.9115332, psnr=10.18, psnr(update)=10.17
# [ 468/ 510] loss(model)=0.0039175, loss(energy)=-60.6448138, psnr=10.19, psnr(update)=10.22
# [ 469/ 510] loss(model)=0.0047713, loss(energy)=-60.9163168, psnr=10.16, psnr(update)=10.17
# [ 470/ 510] loss(model)=0.0047615, loss(energy)=-59.5181348, psnr=10.14, psnr(update)=10.14
# [ 471/ 510] loss(model)=0.0042133, loss(energy)=-59.8080060, psnr=10.17, psnr(update)=10.18
# [ 472/ 510] loss(model)=0.0052635, loss(energy)=-59.0332285, psnr=10.16, psnr(update)=10.12
# [ 473/ 510] loss(model)=0.0047661, loss(energy)=-60.4706769, psnr=10.21, psnr(update)=10.16
# [ 474/ 510] loss(model)=0.0047672, loss(energy)=-60.4273749, psnr=10.24, psnr(update)=10.14
# [ 475/ 510] loss(model)=0.0047053, loss(energy)=-59.7890186, psnr=10.17, psnr(update)=10.20
# [ 476/ 510] loss(model)=0.0059297, loss(energy)=-59.2553204, psnr=10.14, psnr(update)=10.17
# [ 477/ 510] loss(model)=0.0037839, loss(energy)=-60.9407321, psnr=10.20, psnr(update)=10.18
# [ 478/ 510] loss(model)=0.0036784, loss(energy)=-58.0709586, psnr=10.18, psnr(update)=10.21
# [ 479/ 510] loss(model)=0.0053409, loss(energy)=-60.0667508, psnr=10.17, psnr(update)=10.08
# [ 480/ 510] loss(model)=0.0047109, loss(energy)=-59.5651245, psnr=10.16, psnr(update)=10.17
# [ 481/ 510] loss(model)=0.0050260, loss(energy)=-59.7534406, psnr=10.11, psnr(update)=10.22
# [ 482/ 510] loss(model)=0.0041990, loss(energy)=-59.9412680, psnr=10.20, psnr(update)=10.22
# [ 483/ 510] loss(model)=0.0044020, loss(energy)=-61.5333173, psnr=10.24, psnr(update)=10.22
# [ 484/ 510] loss(model)=0.0038126, loss(energy)=-58.9495065, psnr=10.19, psnr(update)=10.20
# [ 485/ 510] loss(model)=0.0047753, loss(energy)=-57.5178403, psnr=10.13, psnr(update)=10.14
# [ 486/ 510] loss(model)=0.0040784, loss(energy)=-59.4109799, psnr=10.18, psnr(update)=10.22
# [ 487/ 510] loss(model)=0.0040728, loss(energy)=-61.0439932, psnr=10.17, psnr(update)=10.19
# [ 488/ 510] loss(model)=0.0040619, loss(energy)=-59.7366214, psnr=10.21, psnr(update)=10.20
# [ 489/ 510] loss(model)=0.0041411, loss(energy)=-59.3213358, psnr=10.16, psnr(update)=10.16
# [ 490/ 510] loss(model)=0.0047993, loss(energy)=-58.9181177, psnr=10.14, psnr(update)=10.21
# [ 491/ 510] loss(model)=0.0047560, loss(energy)=-61.6392856, psnr=10.18, psnr(update)=10.21
# [ 492/ 510] loss(model)=0.0044134, loss(energy)=-60.3545953, psnr=10.17, psnr(update)=10.10
# [ 493/ 510] loss(model)=0.0038994, loss(energy)=-58.6411432, psnr=10.20, psnr(update)=10.19
# [ 494/ 510] loss(model)=0.0050322, loss(energy)=-59.9786795, psnr=10.18, psnr(update)=10.11
# [ 495/ 510] loss(model)=0.0048042, loss(energy)=-61.8449231, psnr=10.19, psnr(update)=10.19
# [ 496/ 510] loss(model)=0.0051037, loss(energy)=-59.8454224, psnr=10.15, psnr(update)=10.14
# [ 497/ 510] loss(model)=0.0048339, loss(energy)=-59.2051315, psnr=10.13, psnr(update)=10.20
# [ 498/ 510] loss(model)=0.0047089, loss(energy)=-58.4318463, psnr=10.12, psnr(update)=10.17
# [ 499/ 510] loss(model)=0.0050005, loss(energy)=-60.5489923, psnr=10.19, psnr(update)=10.16
# [ 500/ 510] loss(model)=0.0048842, loss(energy)=-59.9075766, psnr=10.15, psnr(update)=10.13
# [ 501/ 510] loss(model)=0.0040140, loss(energy)=-59.4378503, psnr=10.19, psnr(update)=10.19
# [ 502/ 510] loss(model)=0.0043105, loss(energy)=-58.5566949, psnr=10.18, psnr(update)=10.19
# [ 503/ 510] loss(model)=0.0040555, loss(energy)=-57.4234296, psnr=10.12, psnr(update)=10.13
# [ 504/ 510] loss(model)=0.0048129, loss(energy)=-59.9704620, psnr=10.20, psnr(update)=10.18
# [ 505/ 510] loss(model)=0.0052907, loss(energy)=-60.0927512, psnr=10.17, psnr(update)=10.20
# [ 506/ 510] loss(model)=0.0040158, loss(energy)=-60.3184247, psnr=10.20, psnr(update)=10.24
# [ 507/ 510] loss(model)=0.0044328, loss(energy)=-60.1993613, psnr=10.20, psnr(update)=10.20
# [ 508/ 510] loss(model)=0.0043534, loss(energy)=-59.0251306, psnr=10.15, psnr(update)=10.17
# [ 509/ 510] loss(model)=0.0044758, loss(energy)=-59.4937744, psnr=10.11, psnr(update)=10.14

# %%
# -------------------------------------------------------------------
# save training results
# -------------------------------------------------------------------         
nRow    = 5 
nCol    = 5
fSize   = 3

fig, ax = plt.subplots(nRow, nCol, figsize=(fSize * nCol, fSize * nRow))

ax[0][0].set_title('loss (model)')
ax[0][0].plot(val_loss_model_mean, color='red')
ax[0][0].fill_between(list(range(optim_length_epoch)), val_loss_model_mean-val_loss_model_std, val_loss_model_mean+val_loss_model_std, color='blue', alpha=0.2)

ax[0][1].set_title('loss (energy)')
ax[0][1].plot(val_loss_energy_mean, color='red')
ax[0][1].fill_between(list(range(optim_length_epoch)), val_loss_energy_mean-val_loss_energy_std, val_loss_energy_mean+val_loss_energy_std, color='blue', alpha=0.2)

ax[0][2].set_title('psnr')
ax[0][2].plot(val_psnr_mean, color='blue', label='y_0')
ax[0][2].plot(val_psnr_update_mean, color='red', label='y_n')
ax[0][2].legend()

for i in range(nCol):
    ax[1][i].set_title('clean')
    ax[1][i].imshow(data[i], 'gray')

for i in range(nCol):
    ax[2][i].set_title('noisy')
    ax[2][i].imshow(data_noise[i], 'gray')

for i in range(nCol):
    ax[3][i].set_title('y_0')
    ax[3][i].imshow(pred[i], 'gray')

for i in range(nCol):
    ax[4][i].set_title('y_n')
    ax[4][i].imshow(pred_update[i], 'gray')

plt.tight_layout()
fig.savefig(file_figure, bbox_inches='tight', dpi=300)
plt.close(fig)
